# %%
import pandas as pd

lists = pd.read_csv('lists.csv', index_col = 'date')

pd.options.display.max_rows = 20

# %%
lists.head(10)
# Out:
#                  time      name    surname      id  rank position  \
# date
# 07 SEP 1999  14:40.59  Gabriela      Szabo   62935   1.0        1
# 07 SEP 1999  14:41.34     Zahra     Ouaziz   68012   2.0        2
# 27 AUG 1999  14:41.82  Gabriela      Szabo   62935   NaN        1
# 07 AUG 1999  14:42.03     Zahra     Ouaziz   68012   NaN        1
# 07 SEP 1999  14:42.03     Irina  Mikitenko  115374   3.0        3
# 27 AUG 1999  14:43.15     Zahra     Ouaziz   68012   NaN        2
# 07 AUG 1999  14:43.54     Paula  Radcliffe   62914   4.0        2
# 27 AUG 1999  14:44.22   Ayelech      Worku  115307   5.0        3
# 20 JUN 1999  14:48.79     Paula  Radcliffe   62914   NaN        1
# 07 SEP 1999  14:49.12     Tegla    Loroupe   61121   6.0        4
#
#                      DOB                    venue nationality
# date
# 07 SEP 1999  14 NOV 1975  Berlin (Olympiastadion)         ROU
# 07 SEP 1999  20 DEC 1969  Berlin (Olympiastadion)         MAR
# ...

# %%
lists['time']
# Out:
# date
# 07 SEP 1999    14:40.59
# 07 SEP 1999    14:41.34
# 27 AUG 1999    14:41.82
# 07 AUG 1999    14:42.03
# 07 SEP 1999    14:42.03
# 27 AUG 1999    14:43.15
# 07 AUG 1999    14:43.54
# 27 AUG 1999    14:44.22
# 20 JUN 1999    14:48.79
# 07 SEP 1999    14:49.12
#                  ...
# 13 JUL 2017    15:34.17
# 26 MAY 2017    15:34.44
# 08 JUL 2017    15:34.60
# 27 MAY 2017    15:34.82
# 02 JUN 2017    15:34.91
# 15 OCT 2017    15:35.31
# 24 MAR 2017    15:35.55
# 02 JUN 2017    15:36.55
# 13 JUL 2017    15:36.74
# 25 AUG 2017     15:27.6
# Name: time, Length: 4979, dtype: object

# %%
lists.sort_values('time')
# Out:
#                  time            name    surname      id   rank position  \
# date
# 06 JUN 2008  14:11.15        Tirunesh     Dibaba  181712    1.0        1
# 02 JUN 2016  14:12.59           Almaz      Ayana  250362    1.0        1
# 22 JUL 2008  14:12.88         Meseret      Defar  171229    2.0        1
# 17 MAY 2015  14:14.32           Almaz      Ayana  250362    1.0        1
# 04 JUL 2015  14:15.41         Genzebe     Dibaba  226511    2.0        1
# 22 MAY 2016  14:16.31           Almaz      Ayana  250362    NaN        1
# 15 JUN 2007  14:16.63         Meseret      Defar  171229    1.0        1
# 08 JUN 2017  14:18.37  Hellen Onsando      Obiri  263953    1.0        1
# 09 SEP 2016  14:18.89           Almaz      Ayana  250362    NaN        1
# 30 MAY 2015  14:19.76         Genzebe     Dibaba  226511    NaN        1
# ...               ...             ...        ...     ...    ...      ...
# 03 JUL 2004  15:59.89         Yesenia    Centeno   76251  318.0       14
# ...
